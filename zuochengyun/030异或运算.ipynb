# %% [markdown]
# ![image.png](attachment:753782a4-f0d3-42e5-b178-35829bdc86e0.png)

# %% [markdown]
# 对于python，该溢出的时候会自动提升位数，所以没办法溢出；可以与上一个0xFFFFFFFF保证是32位的(这里的一个F代表二进制的1111)

# %% [markdown]
# ![image.png](attachment:83cb60ce-eda6-4fb6-b11f-d3b8dc157763.png)

# %% [markdown]
# ![image.png](attachment:8e7aa05c-2af6-4024-a17d-0b12b6bd7ea6.png)
