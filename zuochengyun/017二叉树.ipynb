# %% [markdown]
# **满二叉树**
# 如果一颗二叉树只有度为0的结点和度为2的结点，并且度为0的结点在同一层上，则这颗二叉树为满二叉树
# 深度为k，有2**k-1个结点

# %% [markdown]
# **完全二叉树**
# 在完全二叉树中，除了最底层结点可能没有填满外，其余每层结点数都达到最大值，并且最下面一层的结点都集中在该层最左边的若干位置

# %% [markdown]
# **二叉搜索树**
# 满二叉树和完全二叉树都是没有数值的，二叉搜索树是**有数值的**
# ·若它的左子树不空，则左子树上所有结点的值均小于它的根结点的值；
# ·若它的右子树不空，则右子树上所有结点的值均大于它的根节点；
# ·它的左/右子树也分别为二叉排序树

# %% [markdown]
# **平衡二叉搜索树AVL树**
# 它是一个棵空树或它的左右两个子树的高度差的绝对值不超过1，并且左右两个子树都是一颗平衡二叉树

# %% [markdown]
# 二叉树可以**链式存储**，也可以**顺序存储**
# 链表或者数组![image.png](attachment:00ca2807-95f5-4ec4-9e32-da9b81ea863f.png)

# %% [markdown]
# 二叉树的遍历方式L深度优先遍历和广度优先遍历：
# 1.**深度优先**遍历：先往深走，遇到叶子结点再往回走
# 2.**广度优先**遍历：一层一层的去遍历   、

# %% [markdown]
# ![image.png](attachment:f32e0461-0f8d-47ab-b320-787896372df5.png)
