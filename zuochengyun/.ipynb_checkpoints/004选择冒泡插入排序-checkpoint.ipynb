# %% [markdown]
# ![image.png](attachment:fc05931b-30a5-4fae-863b-0af9cff0ad9e.png)

# %%
class Solution:
    def selection_sort(self, List):
        for i in range(0, len(List)):
            minindex = i
            for j in range(i,len(List)):
                if List[j] < List[minindex]:
                    minindex = j
            List[i], List[minindex] = List[minindex], List[i]
        return List

    def bubble_sort(self, List):
        for i in range(len(List)-1,0,-1):
            for j in range(0, i):
                if List[j] > List[j+1]:
                    List[j], List[j+1] = List[j+1], List[j]
        return List
    def insertion_sort(self, List):
        for i in range(1, len(List)):
            for j in range(i-1, 0, -1):
                if List[j] > List[j+1]:
                    List[j], List[j+1] = List[j+1], List[j]
                    
        return List

# %%
a = [4,5,6,8,3,21,7,2,87,9,90,1,65]

# %%
S = Solution()
S.selection_sort(a)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 21, 65, 87, 90]

# %%
a = [4,5,6,8,3,21,7,2,87,9,90,1,65]
S.bubble_sort(a)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 21, 65, 87, 90]

# %%
a = [4,5,6,8,3,21,7,2,87,9,90,1,65]
S.insertion_sort(a)
# Out:
# [4, 1, 2, 3, 5, 6, 7, 8, 9, 21, 65, 87, 90]

# %%
class Solution:
    def selection_sort(self, List):
        for i in range(0, len(List)):
            minindex = i
            for j in range(i, len(List)):
                if List[j] < List[minindex]:
                    minindex = j
            List[i], List[minindex] = List[minindex], List[i]
        return List

    def bubble_sort(self, List):
        for i in range(len(List)-1,0,-1):
            for j in range(0, i):
                if List[j] > List[j+1]:
                    List[j], List[j+1] = List[j+1], List[j]
                    
        return List
    def insertion_sort(self, List):
        for i in range(1, len(List)):
            for j in range(i-1, 0, -1):
                if List[j] > List[j+1]:
                    List[j], List[j+1] = List[j+1], List[j]
                    
        return List
