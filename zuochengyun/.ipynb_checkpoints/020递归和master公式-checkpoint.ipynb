# %% [markdown]
# ![image.png](attachment:2d939645-83ef-430b-a833-ee9582e48998.png)
# l == r这个情况就是base case，即没有办法再划分了；
# 如果l != r，那么说明还能接着划分，就进行下面的代码

# %% [markdown]
# 中间过程的变量等都压入**系统栈**

# %% [markdown]
# ![image.png](attachment:97318771-7ac9-4153-bf1b-aca5fbc0ac2d.png)
